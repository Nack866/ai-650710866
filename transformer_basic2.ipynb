# %%
# !pip install -U pip transformers
# Out:
# Requirement already satisfied: pip in /usr/local/lib/python3.12/dist-packages (24.1.2)
# Collecting pip
#   Downloading pip-25.2-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (4.56.2)
# Collecting transformers
#   Downloading transformers-4.57.0-py3-none-any.whl.metadata (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.4/41.4 kB 1.9 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers) (3.19.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.35.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from transformers) (2.32.4)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.6.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (2025.3.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (1.1.10)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (2025.8.3)
# Downloading pip-25.2-py3-none-any.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 33.8 MB/s eta 0:00:00
# Downloading transformers-4.57.0-py3-none-any.whl (12.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 143.2 MB/s eta 0:00:00
# Installing collected packages: pip, transformers
#   Attempting uninstall: pip
#     Found existing installation: pip 24.1.2
#     Uninstalling pip-24.1.2:
#       Successfully uninstalled pip-24.1.2
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.56.2
#     Uninstalling transformers-4.56.2:
#       Successfully uninstalled transformers-4.56.2
# Successfully installed pip-25.2 transformers-4.57.0

# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

# %%
checkpoint = 'facebook/nllb-200-distilled-600M'
tokenizer = AutoTokenizer.from_pretrained(checkpoint)
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/564 [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/4.85M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.3M [00:00<?, ?B/s]
# special_tokens_map.json: 0.00B [00:00, ?B/s]

# %%
print(f"{len(tokenizer.vocab)}\n")

tokenizer.vocab
# Out:
# 256204
# {'▁dubbatu': 199392,
#  '▁phuqha': 236265,
#  'േട്ട': 230912,
#  '▁vedr': 51454,
#  '資格': 119097,
#  '▁الذي': 21659,
#  '▁мақса': 31886,
#  'îş': 85212,
#  '▁پڙ': 70208,
#  '▁خېلى': 225535,
#  '▁құпия': 219068,
#  'AK': 33854,
#  '▁बह': 27757,
#  '▁କେତେକ': 149672,
#  '▁preġudizzju': 176994,
#  '▁toes': 156582,
#  'jasiri': 233341,
#  '▁bilýän': 194235,
#  'diem': 75412,
#  'љене': 133689,
#  'chs': 140076,
#  'змо': 25840,
#  '▁hlo': 35116,
#  '▁મત': 134867,
#  '▁liter': 22825,
#  'lägg': 110575,
#  '▁toq': 140241,
#  '▁Pera': 162950,
#  'ில்': 2341,
#  '▁moingon': 247559,
#  'ɣzɩ': 76449,
#  '▁èç': 118072,
#  '▁basakoli': 201177,
#  '▁telef': 16049,
#  'éle': 112681,
#  'ాన': 27991,
#  '▁taksa': 182434,
#  '▁mengalahkan': 172028,
#  '▁விமான': 156601,
#  '▁चंद्र': 156528,
#  '▁Kidistá': 177766,
#  '▁igan': 189523,
#  'цэг': 109163,
#  '▁nth': 24077,
#  '▁ರಲ್ಲಿ': 51907,
#  '▁ulimi': 181964,
#  '▁instal': 66668,
#  '▁kuguma': 144726,
#  '▁مدد': 27739,
#  'atief': 150352,
#  '▁유용한': 180613,
#  '▁boraro': 123428,
#  '▁paýhas': 133472,
#  '▁formen': 129504,
#  '原': 250176,
#  'cas': 7793,
#  '▁Bright': 163687,
#  '▁тай': 45607,
#  'тыусы': 138500,
#  '▁akekho': 219380,
#  '▁potego': 192494,
#  '▁Efraim': 153063,
#  '駛': 254817,
#  '▁hagan': 110645,
#  'fanirwa': 80909,
#  '▁istri': 54252,
#  'ød': 8683,
#  'ġiet': 67291,
#  '▁tózala': 218949,
#  '▁entsha': 114970,
#  '▁կը': 47043,
#  '▁ɲɛminɛ': 230328,
#  '▁ఉద్యో': 86512,
#  'raichte': 83833,
#  '▁fornu': 188012,
#  '▁disanka': 73589,
#  '▁publicación': 179771,
#  '▁nale': 28107,
#  '▁uge': 71004,
#  '▁veste': 140882,
#  '▁stiù': 138627,
#  '▁fact': 24256,
#  '▁sandsyn': 134960,
#  '▁diferent': 93698,
#  '▁սկզբ': 131375,
#  '▁acesta': 133147,
#  '▁ప్రయత్ని': 77471,
#  'พี่': 127906,
#  'གཏ': 11559,
#  'approvazzjoni': 100569,
#  '이의': 109314,
#  '▁közöss': 81142,
#  '▁ھ': 2030,
#  'fetseng': 180444,
#  '▁dow': 24829,
#  'する予定': 138566,
#  '▁ᱚᱱᱟ': 222704,
#  '▁airgead': 106105,
#  '▁بيت': 95005,
#  'wladol': 187894,
#  '▁ամերիկ': 231294,
#  'dew': 82925,
#  'zulu': 23692,
#  '▁inglise': 242306,
#  '▁chosen': 197452,
#  '▁فرانس': 77793,
#  'bye': 31246,
#  '▁граница': 166091,
#  '▁mõlemad': 221606,
#  'мија': 95463,
#  '▁шест': 83560,
#  '▁ngagaduhan': 108072,
#  '▁menya': 67503,
#  '▁дисци': 120350,
#  'พูดว่า': 227407,
#  '▁eskuelaan': 239560,
#  '▁Ose': 98432,
#  '▁kontroles': 156616,
#  '▁அவள்': 64256,
#  '▁parapang': 155790,
#  '▁frisk': 176860,
#  '昭示': 176902,
#  '▁borða': 174274,
#  'zoni': 81218,
#  '▁ýöne': 106648,
#  '▁trū': 107346,
#  '▁tS': 189600,
#  'プラ': 39463,
#  '▁затвора': 189458,
#  'wandiikibwa': 84797,
#  'olotra': 100605,
#  'బడింది': 63704,
#  'することである': 216240,
#  '▁turnī': 158655,
#  '▁grand': 14214,
#  '▁līgums': 199045,
#  'кие': 38483,
#  'ເອ': 142263,
#  'ेंशन': 174433,
#  '▁సందర్భంలో': 222056,
#  '▁ನಡುವ': 85445,
#  '▁intego': 217062,
#  '▁esunguluko': 213619,
#  'ikuar': 166849,
#  '▁Şeýdip': 171509,
#  'དང་ཁ་': 246730,
#  '▁ਵਿਦ': 115507,
#  'θηκαν': 70080,
#  '▁دڵی': 142725,
#  '▁dogara': 132665,
#  '▁әк': 115636,
#  '▁ટેક્સ': 189972,
#  '▁alemán': 149010,
#  '▁കോള': 214223,
#  '▁mtazamo': 194362,
#  '▁prečo': 66709,
#  '▁նորից': 234540,
#  'しばらく': 124735,
#  '▁envers': 161258,
#  '▁ə': 6724,
#  'čių': 10981,
#  '▁ඩ': 121723,
#  '▁vipi': 57959,
#  '▁라고': 48783,
#  '▁chiz': 100332,
#  'λάχιστον': 120860,
#  'чун': 86351,
#  'xtəlif': 204230,
#  'ptir': 91023,
#  '▁háború': 175827,
#  'rivit': 182209,
#  '],': 13612,
#  'keren': 202344,
#  '▁hajm': 230774,
#  'ėsi': 90276,
#  '▁addaa': 162447,
#  '▁komwe': 97745,
#  '▁zgod': 23860,
#  'पनि': 110753,
#  '▁culpa': 57823,
#  'ផល': 57827,
#  '▁miqdori': 236104,
#  '▁biabia': 195761,
#  'ባር': 64548,
#  '▁সীম': 203113,
#  'chuid': 130446,
#  '警': 250698,
#  '속에서': 198426,
#  '▁консульта': 125807,
#  'bau': 38141,
#  '▁bankar': 199637,
#  '▁अक्षर': 216358,
#  '▁eest': 32154,
#  '▁helpen': 80430,
#  '▁Μετά': 135991,
#  '▁diofar': 195196,
#  '▁parim': 124709,
#  '▁toidu': 212170,
#  '▁këdë': 243541,
#  '▁Four': 112839,
#  'ayaa': 32964,
#  '▁32:1': 184437,
#  'megi': 38166,
#  '▁lank': 40840,
#  '윌': 253313,
#  '▁биреү': 110585,
#  '▁молеку': 181417,
#  '▁lette': 187546,
#  '▁=': 5636,
#  '来ました': 124553,
#  'ктән': 109208,
#  '▁Eta': 13027,
#  '▁соста': 70986,
#  '▁jap': 21213,
#  'ႁဝ်း': 64598,
#  'ambula': 43424,
#  '▁Тұ': 125229,
#  '▁දෙනවා': 212180,
#  '▁Kirk': 133500,
#  'الط': 121006,
#  'кый': 191004,
#  'jajajaja': 72980,
#  'hat_Latn': 256065,
#  '▁okukhulu': 141233,
#  'ellan': 148727,
#  '▁RO': 67659,
#  '▁strengthen': 240220,
#  '▁їй': 154318,
#  'ھيو': 95759,
#  '▁يەنە': 39788,
#  'etolo': 215231,
#  'тної': 168340,
#  '▁mencapai': 41887,
#  '▁fait': 10929,
#  '▁վստահ': 125476,
#  '百姓': 115857,
#  '▁repub': 55493,
#  '▁Башҡортостанда': 132772,
#  'jò': 106983,
#  'ພາຍໃນ': 158282,
#  'kwistjoni': 131436,
#  'を形成': 246117,
#  '▁নত্ত': 107504,
#  '▁tempat': 14063,
#  '▁kultur': 23897,
#  '▁hma': 49925,
#  'બત્ત': 178190,
#  '▁peyğəmbər': 151750,
#  'onaid': 196324,
#  '警戒': 225166,
#  '▁fiaraha': 167898,
#  'ಡಾ': 131649,
#  '▁دەتوانێت': 158190,
#  'oirí': 60523,
#  '▁ಬಯ': 41454,
#  '▁mying': 186799,
#  '▁навколо': 176137,
#  '▁potro': 223971,
#  'യില്': 117569,
#  '▁boos': 181637,
#  '▁מסוג': 100724,
#  'важливі': 223531,
#  '▁See': 9703,
#  '▁समाचार': 87885,
#  'ুদ্র': 174887,
#  '▁buot': 152206,
#  '▁होली': 132318,
#  '▁ruko': 156802,
#  'рит': 159334,
#  '▁걱정': 51281,
#  '▁ningún': 67985,
#  'install': 144331,
#  '▁ଆଗରେ': 232991,
#  '▁jada': 217169,
#  'ადგენ': 175532,
#  '▁coali': 197121,
#  'Grup': 178569,
#  '▁nhận': 12239,
#  '▁କିନ୍ତୁ': 24619,
#  '▁χώρες': 150507,
#  '▁Kiebhi': 28805,
#  '심이': 101417,
#  'amut': 48618,
#  '▁shim': 59848,
#  'ongola': 17269,
#  'मा': 1248,
#  '▁།།': 222810,
#  '뀐': 254582,
#  '誠': 252427,
#  '▁אש': 70453,
#  'ཚུ་ལས་': 205387,
#  '▁שות': 213656,
#  '▁sorry': 47745,
#  '▁vyjad': 113781,
#  'avati': 225022,
#  '▁servizz': 134032,
#  '梁': 254902,
#  '附近': 172473,
#  '▁Beispill': 243847,
#  '▁ŋg': 25155,
#  '▁सुरुवात': 139635,
#  '▁WO': 124802,
#  '▁Remember': 142192,
#  '▁zaune': 144910,
#  '▁przeci': 88942,
#  'зімі': 97596,
#  '▁kø': 39537,
#  'けれども': 118228,
#  '히': 249423,
#  '▁miŋ': 199577,
#  '▁segítség': 80357,
#  '▁ମିଶ': 137278,
#  '▁Lind': 67438,
#  'bansa': 122891,
#  'ಾಹ': 40159,
#  '▁Stefan': 117822,
#  '▁ŋö': 242010,
#  'ណ្ណ': 245730,
#  '▁Rebbi': 62897,
#  'odir': 154120,
#  '않': 249185,
#  '▁millors': 131754,
#  '▁ambony': 81141,
#  '▁26:5': 156874,
#  '▁राजनी': 44289,
#  '▁мәслихатының': 119700,
#  '▁ndok': 150828,
#  '▁2023': 172400,
#  '▁supone': 206666,
#  'élem': 176918,
#  'ৰত': 20225,
#  'koof': 171942,
#  '▁Pò': 194920,
#  'യായി': 92423,
#  'дім': 106350,
#  '▁uja': 126530,
#  'ッケ': 133726,
#  'yogo': 152913,
#  '▁देखि': 43798,
#  'ပ်ႇ': 60028,
#  'hatikiza': 124932,
#  '▁collabor': 113411,
#  '▁Kwĩ': 85921,
#  'ходи': 12414,
#  '▁सब्': 120545,
#  '▁පාඩ': 241693,
#  '▁mokslinių': 176990,
#  '▁saņemt': 130253,
#  'inywa': 182401,
#  '▁ڕاو': 214964,
#  '▁如果你': 118496,
#  '▁rekomendu': 238166,
#  '▁דער': 10475,
#  '▁bağımsız': 220436,
#  '込んだ': 137202,
#  '▁близь': 237608,
#  '▁школы': 181662,
#  '▁ಗೊತ್ತು': 196915,
#  '▁بی': 2574,
#  '▁klausimą': 219703,
#  'стен': 36808,
#  '▁gumantung': 157408,
#  '▁šiem': 129540,
#  '▁dræ': 111361,
#  '▁joalo': 20426,
#  '▁теләп': 212998,
#  '▁kgob': 151704,
#  '相互作用': 222843,
#  'onien': 195722,
#  'ོག་སྟོང་': 241607,
#  '▁elää': 171230,
#  '▁vermo': 54695,
#  '困': 251186,
#  'eḍ': 92966,
#  '겠지요': 237054,
#  '▁മൂന്ന': 149801,
#  '▁ய': 14844,
#  '▁οποία': 53062,
#  '▁kejahatan': 176433,
#  '▁colores': 233228,
#  '▁миний': 55313,
#  '▁home': 13003,
#  '▁Nap': 15726,
#  'čat': 134437,
#  '▁רג': 103198,
#  '▁Yakub': 71218,
#  '▁dening': 55542,
#  '▁oms': 75484,
#  'angidi': 165492,
#  '▁Okay': 39917,
#  '剣': 252390,
#  'teus': 103654,
#  '▁fots': 45178,
#  '▁družba': 209243,
#  '▁Irin': 200047,
#  '▁Yali': 163025,
#  'usajja': 83541,
#  '▁chà': 193096,
#  'จะไป': 87101,
#  'తా': 27084,
#  '▁confir': 33567,
#  '▁ôn': 204799,
#  '리': 248575,
#  'ātad': 135439,
#  'elelana': 71945,
#  'んだから': 234335,
#  '▁klasik': 105842,
#  '▁Drama': 134513,
#  'ларының': 34339,
#  '僅': 253429,
#  '▁okrem': 125024,
#  '▁tamata': 14937,
#  '▁usen': 128065,
#  '▁Joon': 98245,
#  'esit': 31271,
#  'ží': 11141,
#  '▁masaya': 44329,
#  '▁saken': 134062,
#  'uwiyang': 193136,
#  '▁виклика': 114519,
#  '▁атындағы': 211791,
#  'φτά': 117188,
#  '▁Пари': 77201,
#  '▁식당': 199677,
#  'ésére': 78826,
#  'curi': 102456,
#  'かれらが': 229604,
#  'ňizi': 162590,
#  '▁fisika': 205536,
#  'leping': 182046,
#  '▁jith': 210781,
#  '递': 254626,
#  '▁πρόσ': 91908,
#  '▁Catiamẽla': 214769,
#  'קשר': 91140,
#  'apinda': 161094,
#  'ترو': 202075,
#  '▁ក្រ': 22887,
#  '▁totus': 166948,
#  '▁ndị': 2540,
#  '▁iyaré': 49571,
#  '▁principios': 85545,
#  '▁Aks': 93283,
#  'တော်မူသော': 171519,
#  '▁ທົ່ວ': 201485,
#  '引退': 190644,
#  '▁분야': 54308,
#  '▁dette': 7723,
#  '▁көт': 129264,
#  '▁ກັບ': 27368,
#  '▁ပုၼ်ႈ': 229978,
#  '▁इहे': 121507,
#  '▁ब्रह्म': 220730,
#  '▁podmi': 130659,
#  '▁ghj': 247837,
#  '▁урна': 125873,
#  'ⵉⵔ': 75761,
#  '▁dukan': 48996,
#  '▁ځینې': 127169,
#  '▁ਅਨੁਸਾਰ': 101434,
#  '▁vug': 93938,
#  'óhun': 226575,
#  '▁Torate': 170408,
#  '▁mängu': 213423,
#  'ishli': 63052,
#  '▁ಇಬ್ಬರು': 228229,
#  'هیچ': 219289,
#  '▁shkol': 195987,
#  '▁karas': 174087,
#  '▁과정은': 156794,
#  'サイズ': 111195,
#  '▁unap': 118845,
#  '줘': 252181,
#  '▁कृत': 58139,
#  '▁Mav': 106639,
#  '▁utja': 219770,
#  'inoti': 147525,
#  'bumwe': 124272,
#  '▁mcm': 71002,
#  'ేందుకు': 197661,
#  '▁dapet': 64368,
#  'amiye': 179628,
#  '▁dulu': 24236,
#  '▁paia': 88882,
#  'ayhu': 153720,
#  '▁1987': 45015,
#  'bileng': 103335,
#  '▁phagamego': 231513,
#  'tande': 181186,
#  'भागी': 112237,
#  'ustu': 22541,
#  'ራፍ': 154707,
#  '▁obbole': 181857,
#  '▁paydo': 172788,
#  '▁mainta': 86708,
#  'летті': 47224,
#  '▁anivon': 195084,
#  '▁གྲངས་འདི་དག་གིས': 202431,
#  'ད་དེ་': 164130,
#  '▁obję': 158424,
#  '▁رفتن': 98222,
#  'ҡу': 91547,
#  'UWA': 177786,
#  '春': 252362,
#  '▁leero': 95547,
#  '▁Ҡ': 16956,
#  'aru': 2933,
#  'લમાં': 65486,
#  '关系': 94055,
#  '▁sharing': 162646,
#  '▁મુલા': 114997,
#  'গ্': 166978,
#  '▁toiminn': 188041,
#  '▁հինգ': 214832,
#  'ink': 1195,
#  'witsa': 58434,
#  '▁Vypad': 124518,
#  'ध': 248614,
#  '▁səs': 143567,
#  'бут': 59733,
#  '▁ọkùnrin': 82690,
#  '▁lelapa': 45855,
#  '▁trening': 163318,
#  '▁eyo': 55101,
#  '▁få': 7806,
#  '▁otázku': 177672,
#  '▁ekun': 237895,
#  '▁странно': 208226,
#  'сүнө': 184863,
#  'Prod': 213083,
#  'жылы': 119636,
#  'siɣ': 154850,
#  '▁ஆச்ச': 178306,
#  '▁kũkwata': 108594,
#  'בור': 18502,
#  'eneyo': 140361,
#  'ления': 20660,
#  '▁Všetky': 134895,
#  'мш': 182579,
#  'fas': 8451,
#  '▁അല്ലാഹുവിന്റെ': 247222,
#  '▁baw': 28766,
#  '▁Marse': 220220,
#  '▁toteut': 144558,
#  '▁moathimo': 170058,
#  '▁nagla': 79477,
#  '▁stavka': 178231,
#  '▁učiniti': 76559,
#  '▁रिहिन': 150226,
#  '▁Fir': 13581,
#  '▁دۆخ': 237873,
#  '▁(3).': 158493,
#  '▁Ibrahim': 29813,
#  '▁जाँ': 136866,
#  '▁necesitan': 196147,
#  '▁miesz': 94530,
#  '▁vaita': 149071,
#  '▁Kusini': 221861,
#  '▁vent': 38004,
#  '▁liten': 61883,
#  '▁неким': 159094,
#  'obnyan': 9095,
#  '▁mũtum': 102588,
#  '▁orinasa': 63930,
#  'taqa': 109878,
#  '▁ယဝ်ႉ။': 239319,
#  'ngani': 205486,
#  'Sal': 35229,
#  'ντ': 107139,
#  '▁196': 5208,
#  '▁Башҡа': 204857,
#  '▁دەگ': 89878,
#  '▁ujung': 164865,
#  'ຶນ': 144571,
#  'ritt': 23714,
#  'uh': 821,
#  'ပုရော': 236211,
#  '▁Фран': 25592,
#  'сі': 1456,
#  '▁pedang': 219080,
#  '▁кандидат': 145541,
#  '▁역할': 44343,
#  '▁Salam': 53893,
#  'гъл': 116865,
#  '▁waNkulunkulu': 122827,
#  '▁מבחי': 166323,
#  '▁meħuda': 224933,
#  '▁Rück': 89932,
#  '▁nostres': 44673,
#  '▁जनसंख्या': 147045,
#  '▁tué': 123847,
#  '▁aceea': 93578,
#  '▁Kee': 166216,
#  'Ki': 45510,
#  'ãngã': 39954,
#  '▁larg': 71216,
#  '▁ବିଚାର': 141397,
#  '▁दृढ़': 242791,
#  'িৰ': 149825,
#  '▁korpor': 86187,
#  '▁sukulu': 72214,
#  '▁njinda': 176325,
#  '▁wodo': 155088,
#  'embangkan': 55961,
#  'の中でも': 190561,
#  'ങ്ങളിൽ': 41881,
#  '▁reikia': 32730,
#  'ficiente': 94464,
#  'ତଙ୍କ': 149992,
#  'ျပာ': 60081,
#  '▁allgemeinen': 195674,
#  '▁बातन': 33604,
#  '▁сақтауға': 231023,
#  'յուս': 75515,
#  '▁batsi': 182926,
#  '▁matatu': 111993,
#  '有限': 228267,
#  'বাহ': 56687,
#  '▁faapotopotoga': 178057,
#  '▁며': 88556,
#  '▁enter': 28665,
#  '▁fadh': 149862,
#  '▁Cup': 56305,
#  '▁prítom': 161046,
#  '▁veliku': 223993,
#  'tette': 179905,
#  'ວິທີການ': 209786,
#  '▁ئېيت': 21405,
#  '▁яких': 52874,
#  '▁ಮಾಡಿದರೆ': 241970,
#  '▁шәкерт': 98651,
#  '▁yatangiye': 208509,
#  '▁kujt': 231765,
#  '▁αποτελεί': 180278,
#  'itshembiso': 121492,
#  'ъне': 163713,
#  '▁подат': 109761,
#  'сле': 5912,
#  'جات': 77062,
#  '▁invite': 194776,
#  '▁pya': 77146,
#  'թեր': 150938,
#  'karatteristiċi': 181047,
#  'cznego': 136607,
#  'upak': 241122,
#  'スー': 74016,
#  'olucion': 189261,
#  '▁конкурс': 133925,
#  '▁פארק': 198240,
#  '▁ଦରକାର': 114894,
#  'fair': 129930,
#  'aknyo': 147461,
#  'erste': 18629,
#  '้า': 2967,
#  '焉': 254774,
#  '▁sɔ': 4593,
#  '▁tādējādi': 154772,
#  '▁mubiri': 142704,
#  'ishini': 26781,
#  'umiri': 99863,
#  '▁چن': 29078,
#  'ંપ': 156990,
#  '▁चेहरे': 193594,
#  'हील': 236860,
#  '▁kiter': 161097,
#  'ニア': 28128,
#  '엄': 250762,
#  '▁Témoins': 146337,
#  'ဘု': 110934,
#  'ội': 9311,
#  '▁مرحبا': 147168,
#  'ངག་': 218569,
#  '▁literatura': 107270,
#  '▁izingane': 96183,
#  '▁raitim': 52934,
#  '▁sept': 28796,
#  '▁ביני': 199604,
#  'sahu': 125187,
#  '▁otla': 235016,
#  '▁kļu': 109522,
#  '▁살았': 134823,
#  '▁tasol': 19159,
#  'აკეთ': 76714,
#  'bilité': 56048,
#  '▁gwoup': 148750,
#  '▁Ore': 140531,
#  'стағы': 103997,
#  'ubusa': 180409,
#  'ⴸ': 255296,
#  '▁מאַ': 43492,
#  '▁sääntö': 163224,
#  '▁Stanford': 151618,
#  'дарын': 69532,
#  'గి': 10958,
#  '▁utk': 69990,
#  '▁প্রতিক': 210596,
#  '▁చేస్తున్నా': 238518,
#  'ateľ': 18262,
#  'אגט': 83053,
#  'fornit': 139324,
#  'ーク': 11938,
#  'นั่น': 23357,
#  '▁pʋyɔɔ': 42271,
#  '▁entonces': 59633,
#  '▁liiketoim': 181152,
#  '▁көс': 84607,
#  '▁kirjo': 57445,
#  '▁kwanak': 199975,
#  '▁Mer': 6561,
#  '▁koliko': 42491,
#  '▁raya': 29641,
#  'ләрдә': 76323,
#  '▁언': 9916,
#  '▁kuns': 99720,
#  '▁uzun': 40382,
#  '▁roynt': 239995,
#  '▁تۆت': 208147,
#  '▁nêz': 175971,
#  '▁עניין': 211627,
#  '▁ئويلى': 216769,
#  'ĩrĩra': 78517,
#  '▁Staten': 166002,
#  'ىمەن': 62761,
#  '▁Bloom': 115184,
#  'jades': 174795,
#  '▁Pozna': 196890,
#  '▁တီ': 172923,
#  'alu': 1415,
#  '▁kawin': 105992,
#  '▁nulla': 97258,
#  'पो': 24721,
#  '▁acknow': 242466,
#  '▁ngăn': 75193,
#  '▁মনো': 132174,
#  'okos': 92895,
#  '▁માણસો': 234031,
#  'hhhhh': 212833,
#  'ほかの': 97760,
#  '午後': 137136,
#  'ňov': 125856,
#  '▁директоры': 132243,
#  'വായി': 222974,
#  '推奨': 136027,
#  'ⵍⴰ': 32008,
#  '್ರಾಯೇ': 230096,
#  '▁Marketing': 80340,
#  '▁bezala': 36846,
#  '▁republiky': 219839,
#  '▁Wadannan': 173838,
#  '▁pajjiżi': 91752,
#  '▁ahat': 178600,
#  '▁misyon': 130248,
#  '▁sova': 126862,
#  'ศรัทธา': 100398,
#  'mʋ': 138714,
#  'אַס': 59939,
#  '▁هذا': 6277,
#  'ғәз': 187751,
#  '▁곳': 13538,
#  '▁សួរ': 145617,
#  '▁omwa': 200991,
#  '▁ምፍ': 137200,
#  '▁کوئی': 13995,
#  '▁ɛyɛɛ': 171638,
#  '▁lowu': 9135,
#  'yor': 2517,
#  'umul': 76034,
#  'arse': 24456,
#  '▁ઓફર': 191481,
#  '▁китептик': 207221,
#  '▁wexxam': 219525,
#  '▁ډا': 175865,
#  '▁लोगो': 165489,
#  '୍ରମ': 79851,
#  '▁ໄດ້ຮັບ': 135812,
#  'ศัพท์': 211210,
#  '▁ચર્ચા': 126462,
#  '雪': 252564,
#  'how': 45017,
#  '▁Dod': 81336,
#  'usie': 162923,
#  '▁ebele': 61572,
#  '▁آتام': 222724,
#  '▁አያ': 73642,
#  '▁уда': 38804,
#  '▁Ez': 3979,
#  'ғы': 1314,
#  'chitira': 75606,
#  'anamura': 166800,
#  '▁baadhi': 91626,
#  'єш': 123030,
#  'Book': 97016,
#  'เข้าใจ': 95145,
#  '▁tokante': 228405,
#  '▁bany': 4072,
#  'വന': 51036,
#  '▁Әгәр': 36436,
#  '▁anghel': 82010,
#  '▁реши': 60505,
#  'anut': 44720,
#  '▁Prá': 161818,
#  '▁ឃើញ': 70111,
#  '▁төз': 136209,
#  '▁Дагы': 242068,
#  '▁supervis': 116263,
#  '▁mun': 1194,
#  'ན་ར': 97295,
#  '▁لگتا': 112732,
#  'lazim': 222577,
#  '▁achị': 132547,
#  '寸': 253901,
#  '▁জ্ঞান': 140660,
#  '▁पत्नी': 54559,
#  'esia': 25032,
#  'クライアント': 141398,
#  '▁باشا': 235022,
#  'yrus': 55671,
#  '▁λέει': 95397,
#  'ugbọn': 33182,
#  'пом': 98919,
#  '▁Егер': 46406,
#  '▁راغ': 243335,
#  '▁သင်္': 195283,
#  '▁نیچے': 128436,
#  '▁достав': 105064,
#  'hulum': 64266,
#  '▁compris': 106661,
#  '▁Висо': 232613,
#  '▁rụrụ': 146434,
#  'werke': 197998,
#  'geze': 89301,
#  '链': 254568,
#  '▁tuvo': 49501,
#  'ོངས་': 19929,
#  '▁wok': 5469,
#  '▁във': 56746,
#  '▁Запа': 98739,
#  'லம்': 55932,
#  '가에': 144680,
#  '▁rahvusvahelise': 218426,
#  '▁altar': 66558,
#  'ciale': 70587,
#  '▁lɩmaɣza': 128914,
#  '▁kolobetšwa': 224213,
#  '▁կապված': 153144,
#  '暑': 253538,
#  '▁Ap': 5244,
#  '▁reprezent': 109806,
#  '▁samun': 32243,
#  '್ಯು': 163779,
#  'meter': 193990,
#  'pila': 26739,
#  '▁орун': 172141,
#  '▁чыгы': 46117,
#  '▁майбутньому': 219715,
#  '▁kunoita': 212503,
#  '▁Valsts': 64324,
#  '▁һайын': 113095,
#  '▁သည္': 81173,
#  '▁ža': 159602,
#  '▁betekent': 135287,
#  '▁capì': 201716,
#  'шыбыз': 74664,
#  '▁безпеки': 99298,
#  'زيد': 132343,
#  '軍': 250357,
#  'hawe': 91481,
#  '▁stroš': 81110,
#  '▁makat': 30825,
#  '༨': 252323,
#  '점이': 94325,
#  'गो': 9748,
#  '▁ඉස්ස': 153266,
#  '이너': 131002,
#  '▁аман': 194202,
#  '/22': 205704,
#  'থে': 16510,
#  '▁dünyaya': 172895,
#  '࿒': 253513,
#  '▁Кеңес': 247146,
#  '▁norsk': 179283,
#  'gapä': 224849,
#  'bọmi': 219872,
#  '▁munt': 63078,
#  'andlheni': 89036,
#  '▁تك': 70105,
#  '▁din': 1698,
#  '▁Bugungi': 213450,
#  'раткан': 120302,
#  '▁entspre': 87809,
#  'ayile': 244286,
#  '▁tattalin': 151746,
#  '▁લાભ': 88169,
#  'ская': 51926,
#  '▁op': 636,
#  'cadh': 47464,
#  'stående': 98197,
#  'Melika': 151220,
#  '▁10:24,': 91155,
#  'ನ್ನಿ': 226580,
#  '▁ତୁମ୍ଭ': 48027,
#  'বাৰ': 53149,
#  '▁compensa': 143506,
#  'ಕ್': 2656,
#  '▁esikoleni': 215589,
#  'ideach': 156592,
#  '▁número': 31897,
#  'upuk': 77761,
#  '▁Wiki': 104559,
#  '▁မႂ်း': 222865,
#  '▁Иман': 215936,
#  '▁என்ன': 10496,
#  'ཁོང་ལུ་': 78330,
#  '▁بند': 14555,
#  'jip': 81521,
#  '▁disediakan': 133248,
#  'laleho': 213275,
#  '▁కు': 21649,
#  '▁Auto': 35333,
#  '▁kaugaling': 40596,
#  '▁bað': 216303,
#  '▁angga': 124704,
#  '▁Θεός': 167014,
#  '▁eeb': 219313,
#  'atuatua': 81588,
#  '▁ঙসি': 229922,
#  '▁Մարդ': 152871,
#  'ཕེ་': 210220,
#  '▁Rooma': 207161,
#  '▁anaa': 16100,
#  '▁Доколку': 226261,
#  '▁കിട': 121215,
#  '▁Ulaya': 102809,
#  '▁yetir': 222000,
#  '▁בשבוע': 226643,
#  '▁ĩndĩ': 24780,
#  'èn': 4051,
#  '▁Aussch': 122175,
#  'ხსენ': 221650,
#  '▁química': 170929,
#  'スタンの': 242756,
#  'asino': 92032,
#  'ときは': 91787,
#  '▁mion': 201119,
#  '▁Había': 211612,
#  'בחר': 160631,
#  '▁келген': 27118,
#  'îyê': 63842,
#  '☞': 254918,
#  '▁эмо': 195470,
#  '▁Значи': 58026,
#  '▁üksi': 238080,
#  '▁cymun': 213284,
#  'လှုပ်ရှား': 215582,
#  '▁అర్థ': 64588,
#  '▁lekisa': 11017,
#  'িত্ৰ': 156092,
#  '▁один': 30157,
#  'མཇ': 64539,
#  '▁ভাৰতৰ': 117109,
#  'ɔmɛ': 132443,
#  'onekele': 203880,
#  '▁oku': 834,
#  '▁အစ': 47320,
#  '京': 251818,
#  '▁gammachi': 135429,
#  '▁metro': 67859,
#  '上げて': 186539,
#  '▁oks': 216995,
#  'ன்னு': 55009,
#  'Mark': 144750,
#  '▁eyinom': 131133,
#  '▁あるいは': 117588,
#  '▁damuwa': 119888,
#  '▁جاپان': 246390,
#  '▁Yosefa': 152546,
#  'കരമായ': 129034,
#  '▁mazunda': 200922,
#  '▁Cuireann': 230524,
#  '▁milione': 236824,
#  '▁ñaw': 72555,
#  '▁1959.': 231439,
#  'lenga': 112053,
#  'eera': 152508,
#  '▁Keek': 183785,
#  '▁chaizvoizvo': 247037,
#  '▁freastal': 190102,
#  '▁هەب': 41241,
#  '▁salu': 31260,
#  '▁ndech': 137560,
#  '▁मोदी': 63302,
#  '▁참조': 96970,
#  '▁Hogyan': 106590,
#  '▁dialek': 227140,
#  '▁בל': 24819,
#  'tasz': 224244,
#  '▁zadnje': 173409,
#  'isarema': 106533,
#  '▁Hoćeš': 193808,
#  '出生': 136682,
#  ...}

# %%
thai_char_min = 0x0E00
thai_char_max = 0x0E7F

thai_tokens = [
    token for token in tokenizer.vocab.keys()
    if any(thai_char_min <= ord(char) <= thai_char_max for char in token)
]

thai_token_count = len(thai_tokens)
sample_size = 20
thai_tokens_sample = thai_tokens[:sample_size]


print(f"{thai_token_count}\n")
for token in thai_tokens_sample:
  print(token)
# Out:
# 1712
#
# ุง
# ตัด
# ▁ดี
# คนหนึ่ง
# ปี
# นิ
# ▁โลก
# ▁พระเจ้า
# เหมือนกัน
# คู่
# เก
# ให้เขา
# ติ
# พร
# ▁โอ
# นาย
# หรือไม่
# เท
# ํานา
# ๋

# %%
import tensorflow as tf
import plotly.graph_objects as go
import plotly.express as px
from plotly.subplots import make_subplots
import numpy as np
import math

# %%
sentence = 'Work hard, play harder'

# %%
cleaned_sentence = sentence.replace(',', '')
cleaned_sentence
# Out:
# 'Work hard play harder'

# %%
words = cleaned_sentence.split()
words
# Out:
# ['Work', 'hard', 'play', 'harder']

# %%
sorted_words = sorted(words)
sorted_words
# Out:
# ['Work', 'hard', 'harder', 'play']

# %%
dc = {word: index for index, word in enumerate(sorted_words)}
dc
# Out:
# {'Work': 0, 'hard': 1, 'harder': 2, 'play': 3}

# %%
sentence_int = tf.constant(
    [dc[s] for s in sentence.replace(',', '').split()],
    dtype=tf.int32
)

# %%
print(sentence)
print(sentence_int)
# Out:
# Work hard, play harder
# tf.Tensor([0 1 3 2], shape=(4,), dtype=int32)

# %%
# สร้าง embedding layer
tf.random.set_seed(123)
vocab_size = 50_000
embedding_dim = 2

embed = tf.keras.layers.Embedding(input_dim=vocab_size, output_dim=embedding_dim)

# %%
embedded_sentence = embed(sentence_int)

# %%
embedded_sentence
# Out:
# <tf.Tensor: shape=(4, 2), dtype=float32, numpy=
# array([[-0.01490884,  0.01237174],
#        [-0.02347864, -0.0334612 ],
#        [ 0.04650122, -0.0373578 ],
#        [ 0.00282909,  0.00648215]], dtype=float32)>

# %%
tf.random.set_seed(123)
vocab_size = 50_000
embedding_dim = 2

dummy_input = tf.constant([0, 1, 2], dtype=tf.int32)

# Case 1 Default initializer (RandomUniform(-0.05, 0.05))
embed_default = tf.keras.layers.Embedding(input_dim=vocab_size, output_dim=embedding_dim)
_ = embed_default(dummy_input) # เรียกใช้งาน layer เพื่อสร้าง weights
weights_default = embed_default.get_weights()[0].flatten()
weights_default.shape
# Out:
# (100000,)

# %%
# Case 2 GlorotUniform initializer
tf.random.set_seed(123)
embed_glorot = tf.keras.layers.Embedding(
    input_dim=vocab_size,
    output_dim=embedding_dim,
    embeddings_initializer=tf.keras.initializers.GlorotUniform()
)
_ = embed_glorot(dummy_input) # เรียกใช้งาน layer เพื่อสร้าง weights
weights_glorot = embed_glorot.get_weights()[0].flatten()
weights_glorot.shape
# Out:
# (100000,)

# %%
fig = make_subplots(rows=1, cols=1)

fig.add_trace(go.Histogram(x=weights_default, nbinsx=50, name="Default Uniform [-0.05, 0.05]", opacity=0.6))
fig.add_trace(go.Histogram(x=weights_glorot, nbinsx=50, name="Glorot Uniform", opacity=0.6))

fig.update_layout(
    title_text='Embedding Layer Initialization Comparison',
    xaxis_title_text='Weight values',
    yaxis_title_text='Frequency',
    barmode='overlay',
    legend_orientation="h",
    legend_yanchor="bottom",
    legend_y=1.02,
    legend_xanchor="right",
    legend_x=1
)

fig.show()

print("Default initializer range ", weights_default.min(), weights_default.max())
print("Glorot initializer range ", weights_glorot.min(), weights_glorot.max())
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="07512ae5-e904-4f97-8431-81b6cf618e7b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("07512ae5-e904-4f97-8431-81b6cf618e7b")) {                    Plotly.newPlot(                        "07512ae5-e904-4f97-8431-81b6cf618e7b",                        [{"name":"Default Uniform [-0.05, 0.05]","nbinsx":50,"opacity":0.6,"x":[-0.018193662,-0.031913772,-0.023062134,0.01709726,-0.03648741,0.004230641,0.0046411045,0.021078024,0.010479379,-0.0027136095,0.01328272,0.036747325,-0.0052081235,0.028610919,-0.01438842,-0.026606465,0.02616382,0.0016015396,0.043468464,0.030593399,0.03702936,-0.009480454,0.01847637,-0.045774378,0.04782026,-0.014668535,0.034062926,0.019925226,0.0058570504,0.022276226,-0.023284853,0.010843266,-0.039052118,-0.03143399,0.0196332,-0.043082394,-0.022782696,-0.0064551607,0.006621383,0.045030896,-0.044357013,-0.023372365,0.0069803484,0.04099259,-0.034458995,-0.0394393,0.041777182,-0.026054943,-0.031561412,0.046390425,0.04573686,0.012073707,-0.015572894,0.0036149994,-0.034862805,0.033910487,-0.015263617,0.005450569,0.04484773,0.022976253,-0.030058825,0.014037561,0.00095991045,0.020675506,-0.018311419,-0.025478637,0.033128206,-0.015210617,-0.0035165176,0.0034858212,-0.0193043,-0.030212963,0.0016248114,-0.049418997,0.000058054924,-0.0065530166,-0.017122507,-0.012198329,0.025006894,-0.007404648,-0.008051835,0.013632964,0.012846675,-0.019439925,-0.026367819,0.034214806,0.0118968,0.024756972,-0.015629947,-0.002067577,0.0017539859,-0.03289044,-0.03436383,-0.041790545,-0.036351524,-0.009827912,0.026471626,-0.0012634881,-0.0026357286,0.04871707,-0.0492859,0.022464026,0.033149634,0.022434745,-0.04808688,0.02934153,-0.01783935,0.012519766,0.024866711,-0.047311105,0.031068098,0.016335893,0.04569644,-0.046274878,-0.021517504,-0.031320572,0.011775278,0.02964392,-0.017856635,0.030946467,-0.008016873,0.031893697,0.016937103,0.015400682,0.033085477,-0.02263614,-0.029976595,0.028259408,0.04677785,-0.030849291,0.017844368,-0.009835254,0.0003600344,-0.010972071,-0.03103063,0.04539449,0.04355171,-0.04724219,-0.023045171,0.04910055,0.014714625,-0.048894536,-0.042481672,-0.002537571,0.020821344,-0.028091563,-0.013562333,0.01089678,0.031031575,0.047036815,0.008513462,0.010616459,0.008199383,0.0011672266,-0.028494705,-0.03244667,0.037377145,-0.026904166,-0.017164398,-0.03801025,0.023232292,-0.017814659,-0.04798311,0.040306415,0.0025036335,-0.030117512,-0.004989207,-0.037895523,0.021280777,0.03222848,-0.0067052953,0.008018695,-0.008025765,-0.033626724,0.0097556,-0.029054761,0.028198708,0.040367354,0.048700143,0.04123802,0.0028641336,0.03580228,-0.022109509,-0.027902722,0.04139859,-0.026428854,0.014214005,-0.00093215704,0.04009595,0.0011821017,-0.047408856,0.04863486,-0.029643238,0.019148435,0.012957718,0.0003466606,0.043631744,0.034654323,-0.027503205,-0.005567979,-0.047169626,-0.04376346,0.04202846,0.01816808,0.046719182,0.0248341,-0.011685811,-0.04546063,-0.007923532,-0.025263323,-0.035892487,-0.025049305,-0.03422097,0.012774792,0.002469577,0.023639988,0.022601213,-0.04202353,-0.009014346,-0.03503094,-0.0028563142,0.00024949387,-0.044680666,-0.00651728,0.038213562,0.0099157095,0.042198148,0.0034082904,-0.032547094,0.024911415,-0.025748039,0.04422119,0.014299218,-0.015724111,0.023227524,0.0082137585,-0.023707688,0.029214386,0.03931688,0.04386108,0.012452852,-0.010028042,0.0044736266,-0.01370107,0.017182615,-0.014362574,-0.040562175,0.018613983,0.030125346,0.031357776,0.034209754,0.038334314,-0.021759545,0.03496449,0.023038875,0.030043852,-0.035194777,0.04342134,-0.00090627745,-0.04548167,-0.001057636,0.005171489,0.032058526,-0.01071962,0.028240789,-0.04947666,0.048180845,0.01663493,-0.024383832,-0.046244074,0.008924257,-0.026156127,0.034 ...
# Default initializer range  -0.049999084 0.049999047
# Glorot initializer range  -0.010954047 0.010953779

# %%
def glorot_uniform_limits(fan_in, fan_out):
    limit = math.sqrt(6.0 / (fan_in + fan_out))
    a, b = -limit, limit
    return a, b

# ตัวอย่าง Embedding layer (vocab_size=50000, embedding_dim=2)
fan_in = 50000
fan_out = 2

a, b = glorot_uniform_limits(fan_in, fan_out)
print("Glorot Uniform a =", a)
print("Glorot Uniform b =", b)
# Out:
# Glorot Uniform a = -0.010954232067652772
# Glorot Uniform b = 0.010954232067652772

# %%
model = AutoModelForSeq2SeqLM.from_pretrained(checkpoint)
# Out:
# config.json:   0%|          | 0.00/846 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/2.46G [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/2.46G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/189 [00:00<?, ?B/s]

# %%
token_embedding_layer = model.model.encoder.embed_tokens
token_embedding_layer.weight.shape
# Out:
# torch.Size([256206, 1024])

# %%
long_sentence = "In the vast realm of natural language processing, understanding the nuances of how models handle sequential data is crucial. Positional encoding plays a vital role in providing this essential information to the model, allowing it to differentiate between words at different positions in a sentence, which is fundamental for tasks like translation, summarization, and text generation."

# %%
tokens = tokenizer(long_sentence, return_tensors="pt")

print(tokens['input_ids'][0])
# Out:
# tensor([256047,    717,    349,  14430,  12284, 248070,    452,  25307,  65445,
#         157278, 248079, 133930,    349,    713,  75831,    452,  11657, 141057,
#          47274, 116914, 124785,   6067,    248, 182071, 248075,  12013,  58409,
#          12025, 246156,   3054,    705,      9, 104781,  76065,    108, 174693,
#           3423, 140515,  18781,    202,    349,  14916, 248079,  82935,     87,
#            796,    202,  53054,    502,  25914,  51744,    230,  30158, 199073,
#            108,      9, 109267, 248079,   9089,    248,  75529,    351, 226047,
#           6399, 200356, 248079,   2493, 109207, 181953, 248079,    540,  35883,
#         120531, 248075,      2])

# %%
len(tokens['input_ids'][0])
# Out:
# 75

# %%
token_embedding_layer(tokens['input_ids'][0][0]).shape
# Out:
# torch.Size([1024])

# %%
token_embeddings = token_embedding_layer(tokens['input_ids'][0])

print("Token Embedding Matrix shape", token_embeddings.shape)
token_embeddings
# Out:
# Token Embedding Matrix shape torch.Size([75, 1024])
# tensor([[-5.0000e+00, -1.2725e+00, -9.3604e-01,  ..., -1.8297e+01,
#          -9.1328e+00, -1.0672e+01],
#         [ 2.6416e-01,  2.6831e-01,  2.0117e-01,  ...,  3.2715e+00,
#          -3.2402e+00,  3.1738e+00],
#         [ 4.3579e-01, -2.3352e-01,  2.6825e-02,  ...,  5.4648e+00,
#           2.7129e+00,  5.5430e+00],
#         ...,
#         [ 8.5859e+00, -4.5391e+00, -4.7314e-01,  ..., -7.9529e-02,
#           7.4844e+00, -7.5156e+00],
#         [-2.4863e+00, -2.7515e-01,  5.6114e-03,  ...,  1.0180e+01,
#          -7.2422e+00, -4.8047e+00],
#         [-7.8320e-01, -9.0527e-01, -9.4482e-01,  ...,  3.1078e+01,
#          -8.1494e-01, -8.7354e-01]], grad_fn=<MulBackward0>)

# %%
import plotly.express as px

token_embeddings_np = token_embeddings.detach().numpy()

fig = px.imshow(
    token_embeddings_np,
    color_continuous_scale="RdBu",
    labels=dict(x="Embedding Dimension", y="Token Index", color="Value"),
    title="Token Embedding Heatmap"
)

fig.update_xaxes(side="top")
fig.update_layout(height=500, width=900)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="923fac9a-9e4f-4004-8e07-5632e031468f" class="plotly-graph-div" style="height:500px; width:900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("923fac9a-9e4f-4004-8e07-5632e031468f")) {                    Plotly.newPlot(                        "923fac9a-9e4f-4004-8e07-5632e031468f",                        [{"coloraxis":"coloraxis","name":"0","z":[[-5.0,-1.2724609,-0.93603516,-0.83203125,-2.8164062,-1.4824219,-1.4541016,-1.5322266,-2.0976562,-1.3632812,-1.3916016,-0.8466797,-0.40673828,-2.1171875,-2.9785156,-5.9257812,-3.2480469,-3.2265625,-5.4296875,-4.6445312,-4.6210938,-2.7578125,1.6699219,0.23669434,2.6699219,0.6894531,2.1640625,-1.4003906,-1.5332031,1.078125,0.27319336,-0.044677734,-4.484375,2.7148438,-0.82714844,-0.9248047,-1.4833984,1.5966797,0.3942871,2.7675781,-0.18151855,-1.4208984,1.4765625,-3.5234375,-1.9033203,-0.36523438,-3.0449219,-7.0078125,3.3378906,-2.4453125,-1.21875,0.6464844,-0.20788574,0.50927734,-0.35546875,2.6171875,-1.484375,-7.21875,-1.6210938,-4.1679688,-6.3476562,0.6245117,-0.8540039,-0.36621094,0.53759766,-4.03125,-1.4160156,-1.6035156,-0.20056152,-2.6367188,0.5800781,-4.2421875,-1.0517578,1.6572266,-3.7011719,-2.1425781,-2.3203125,-0.46142578,-3.1484375,-3.5039062,5.1484375,1.5410156,-2.4667969,1.8359375,-0.8930664,1.2636719,-2.5976562,1.8720703,-1.9160156,1.6894531,-0.9248047,-3.6503906,-2.6464844,3.9433594,-1.8027344,0.08276367,-2.3632812,-0.3720703,-1.2607422,-1.0986328,0.82666016,-2.9101562,-0.7949219,3.4023438,3.4804688,-5.0664062,1.2001953,-2.8222656,-0.0925293,-0.06573486,-4.15625,-0.24804688,-5.2421875,-5.2070312,-1.1210938,-2.1269531,-0.9296875,1.3291016,0.5756836,3.2910156,0.028930664,-3.2949219,-0.74902344,1.9746094,3.2324219,-2.9824219,-4.078125,2.9355469,-0.37890625,-6.0429688,-1.1982422,5.2929688,-0.9555664,-1.0087891,-2.4609375,-2.8320312,7.0390625,1.34375,6.0195312,-4.3007812,-0.33691406,1.3554688,1.9746094,0.88964844,-0.8432617,-1.1689453,2.0429688,-3.375,-2.2167969,-1.0732422,-6.8984375,5.59375,0.70751953,-2.4511719,1.0996094,2.953125,1.5742188,0.7495117,-4.53125,-2.7207031,2.3007812,0.19958496,1.5048828,-2.625,4.9140625,1.2363281,-1.4033203,-0.7739258,2.9023438,-1.9794922,0.5097656,-5.03125,4.3164062,-1.4628906,-3.6289062,7.9023438,-5.4101562,-0.79541016,1.2724609,-3.03125,-3.2617188,-0.7285156,9.453125,6.8710938,-0.78027344,0.8461914,-0.028656006,-1.4453125,-0.89697266,0.20361328,-5.5234375,-3.1992188,0.09460449,5.4921875,-2.9335938,5.6484375,0.92285156,2.1542969,-3.6738281,-2.5722656,-5.1953125,-4.4296875,6.0625,2.1171875,-0.19140625,2.3886719,-2.3144531,-1.4082031,1.1728516,9.0859375,-5.3789062,-0.14526367,-3.1972656,1.8076172,0.8041992,2.4199219,-0.009849548,-6.2070312,-1.6171875,-3.8027344,2.0898438,-2.5351562,0.86816406,0.17224121,-0.5800781,3.7070312,1.9980469,5.015625,-1.7001953,-0.2734375,-1.4921875,3.2675781,-1.4570312,-3.8964844,-1.7021484,-5.0351562,2.5410156,-4.4414062,-2.9394531,9.359375,-0.703125,-0.5439453,-11.515625,4.1367188,6.640625,2.7636719,-2.6054688,-0.5625,1.6259766,0.94140625,0.2746582,0.24401855,-5.3671875,4.6367188,-5.25,6.1484375,-5.5429688,-0.3149414,-2.1875,-2.0859375,-1.1806641,7.3671875,-0.17993164,-1.1494141,-15.9296875,-1.5449219,-3.7226562,-4.6484375,3.0507812,5.1835938,-2.4550781,3.71875,-0.9057617,8.40625,0.1361084,-4.65625,3.203125,0.28466797,-7.28125,-2.9941406,-5.0625,0.92578125,-12.6796875,-5.2929688,0.47802734,18.0625,-11.078125,3.34375,-3.3222656,0.3605957,-6.3164062,-17.1875,3.6796875,-4.4257812,-8.4375,-6.2578125,16.046875,-4.4570312,0.10467529,0.18127441,-4.0664062,-0.4375,1.3125,-1.5859375,-3.6503906,-5.1875,0.32910156,-3.6367188,-3.1835938,-1.5380859,-2.1601562,2.2910156,2.0507812,4.1367188,3.1503906,-0.33325195,-0.03668213,0.8671875,-2.8515625,-7.3359375,-2.9296875,-4.6015625,0.0 ...

# %%
d = embedded_sentence.shape[-1]
d
# Out:
# 2

# %%
d_q, d_k, d_v = 2, 2, 4

d_q, d_k, d_v
# Out:
# (2, 2, 4)

# %%
tf.random.set_seed(123)
W_query = tf.Variable(tf.random.uniform((d, d_q)), trainable=True)
W_key   = tf.Variable(tf.random.uniform((d, d_k)), trainable=True)
W_value = tf.Variable(tf.random.uniform((d, d_v)), trainable=True)

# %%
print(W_query.shape, W_key.shape, W_value.shape)
# Out:
# (2, 2) (2, 2) (2, 4)

# %%
W_query
# Out:
# <tf.Variable 'Variable:0' shape=(2, 2) dtype=float32, numpy=
# array([[0.12615311, 0.5727513 ],
#        [0.2993133 , 0.5461836 ]], dtype=float32)>

# %%
W_key
# Out:
# <tf.Variable 'Variable:0' shape=(2, 2) dtype=float32, numpy=
# array([[0.88968754, 0.12354946],
#        [0.7718717 , 0.6850728 ]], dtype=float32)>

# %%
W_value
# Out:
# <tf.Variable 'Variable:0' shape=(2, 4) dtype=float32, numpy=
# array([[0.48962688, 0.5857923 , 0.36451697, 0.6550509 ],
#        [0.9075084 , 0.37557673, 0.6882372 , 0.25384045]], dtype=float32)>

# %%
embedded_sentence
# Out:
# <tf.Tensor: shape=(4, 2), dtype=float32, numpy=
# array([[-0.01490884,  0.01237174],
#        [-0.02347864, -0.0334612 ],
#        [ 0.04650122, -0.0373578 ],
#        [ 0.00282909,  0.00648215]], dtype=float32)>

# %%
queries = tf.matmul(embedded_sentence, W_query)
keys    = tf.matmul(embedded_sentence, W_key)
values  = tf.matmul(embedded_sentence, W_value)

# %%
print("Queries shape", queries.shape)
queries
# Out:
# Queries shape (4, 2)
# <tf.Tensor: shape=(4, 2), dtype=float32, numpy=
# array([[ 0.00182223, -0.00178181],
#        [-0.01297729, -0.03172338],
#        [-0.00531541,  0.00622942],
#        [ 0.00229709,  0.0051608 ]], dtype=float32)>

# %%
print("Keys shape", keys.shape)
keys
# Out:
# Keys shape (4, 2)
# <tf.Tensor: shape=(4, 2), dtype=float32, numpy=
# array([[-0.00371481,  0.00663356],
#        [-0.04671641, -0.02582413],
#        [ 0.01253613, -0.01984761],
#        [ 0.00752039,  0.00479027]], dtype=float32)>

# %%
print("Values shape", values.shape)
values
# Out:
# Values shape (4, 4)
# <tf.Tensor: shape=(4, 4), dtype=float32, numpy=
# array([[ 0.00392769, -0.00408694,  0.00308017, -0.0066256 ],
#        [-0.04186209, -0.02632086, -0.03158761, -0.02387351],
#        [-0.01113426,  0.01320934, -0.00876054,  0.02097775],
#        [ 0.0072678 ,  0.0040918 ,  0.0054925 ,  0.00349863]],
#       dtype=float32)>

# %%
omega = tf.matmul(queries, keys, transpose_b=True)

print("Omega shape", omega.shape)
print("Omega (Unnormalized attention weights)")
print(omega)
# Out:
# Omega shape (4, 4)
# Omega (Unnormalized attention weights)
# tf.Tensor(
# [[-1.85890203e-05 -3.91142494e-05  5.82084758e-05  5.16850196e-06]
#  [-1.62230906e-04  1.42548094e-03  4.66948259e-04 -2.49557925e-04]
#  [ 6.10690040e-05  8.74475663e-05 -1.90273786e-04 -1.01333335e-05]
#  [ 2.57012725e-05 -2.40585141e-04 -7.36329966e-05  4.19966818e-05]], shape=(4, 4), dtype=float32)

# %%
d_k = tf.cast(d_k, tf.float32)

scaled_omega = omega / tf.sqrt(d_k)

attention_weights = tf.nn.softmax(scaled_omega, axis=-1)

print("Attention Weights")
print(attention_weights)
# Out:
# Attention Weights
# tf.Tensor(
# [[0.24999647 0.24999283 0.25001004 0.25000066]
#  [0.24990587 0.2501866  0.25001708 0.24989045]
#  [0.25001308 0.25001776 0.24996866 0.2500005 ]
#  [0.25001544 0.24996838 0.24999787 0.25001833]], shape=(4, 4), dtype=float32)

# %%
row_sums = tf.reduce_sum(attention_weights, axis=-1)

print("Sum of each row in attention_weights")
row_sums
# Out:
# Sum of each row in attention_weights
# <tf.Tensor: shape=(4,), dtype=float32, numpy=array([1., 1., 1., 1.], dtype=float32)>

# %%
context_vector = tf.matmul(attention_weights, values)

print("Context Vector shape", context_vector.shape)
print(context_vector)
# Out:
# Context Vector shape (4, 4)
# tf.Tensor(
# [[-0.01045004 -0.00327633 -0.00794374 -0.00150528]
#  [-0.01045938 -0.00328141 -0.0079508  -0.00150954]
#  [-0.01045056 -0.0032776  -0.00794411 -0.00150685]
#  [-0.01044867 -0.00327585 -0.0079427  -0.00150501]], shape=(4, 4), dtype=float32)

# %%
class SelfAttention(tf.keras.layers.Layer):
    def __init__(self, d_in, d_out_kq, d_out_v):
        super().__init__()
        self.d_out_kq = d_out_kq

        self.W_query = tf.Variable(
            tf.random.uniform((d_in, d_out_kq)), trainable=True
        )
        self.W_key = tf.Variable(
            tf.random.uniform((d_in, d_out_kq)), trainable=True
        )
        self.W_value = tf.Variable(
            tf.random.uniform((d_in, d_out_v)), trainable=True
        )

    def call(self, x):
        keys = tf.matmul(x, self.W_key)      # [T, d_out_kq]
        queries = tf.matmul(x, self.W_query) # [T, d_out_kq]
        values = tf.matmul(x, self.W_value)  # [T, d_out_v]

        # Attention scores: QKᵀ
        attn_scores = tf.matmul(queries, keys, transpose_b=True)  # [T, T]

        # Softmax (scaled by sqrt(d_k))
        attn_weights = tf.nn.softmax(
            attn_scores / tf.math.sqrt(tf.cast(self.d_out_kq, tf.float32)), axis=-1
        )  # [T, T]

        # Weighted sum
        context_vec = tf.matmul(attn_weights, values)  # [T, d_out_v]
        return context_vec

# %%
tf.random.set_seed(123)

d_in, d_out_kq, d_out_v = 2, 2, 4

sa = SelfAttention(d_in, d_out_kq, d_out_v)

out = sa(embedded_sentence)

print(out.shape)  # (T, d_out_v)
print(out.numpy())
# Out:
# (4, 4)
# [[-0.01045004 -0.00327633 -0.00794374 -0.00150528]
#  [-0.01045938 -0.00328141 -0.0079508  -0.00150954]
#  [-0.01045056 -0.0032776  -0.00794411 -0.00150685]
#  [-0.01044867 -0.00327585 -0.0079427  -0.00150501]]

# %%
class MultiHeadAttentionWrapper(tf.keras.layers.Layer):
    def __init__(self, d_in, d_out_kq, d_out_v, num_heads):
        super().__init__()
        self.heads = [
            SelfAttention(d_in, d_out_kq, d_out_v)
            for _ in range(num_heads)
        ]

    def call(self, x):
        # รันทุก head แล้ว concat ตามแกนสุดท้าย
        head_outputs = [head(x) for head in self.heads]   # list of [T, d_out_v]
        return tf.concat(head_outputs, axis=-1)           # [T, num_heads * d_out_v]

# %%
tf.random.set_seed(123)

d_in, d_out_kq, d_out_v = 2, 2, 1

sa = SelfAttention(d_in, d_out_kq, d_out_v)

# ถ้า embedded_sentence.shape = [T, d_in] เช่น [6, 3]
out = sa(embedded_sentence)

print(out.shape)   # (T, d_out_v) -> (6, 1)
print(out.numpy())
# Out:
# (4, 1)
# [[-0.00627048]
#  [-0.00627706]
#  [-0.00627129]
#  [-0.00626964]]

# %%
tf.random.set_seed(123)

mha = MultiHeadAttentionWrapper(
    d_in, d_out_kq, d_out_v, num_heads=3
)

# run MHA
context_vecs = mha(embedded_sentence)   # [T, num_heads * d_out_v]

print(context_vecs)
print("context_vecs.shape:", context_vecs.shape)
# Out:
# tf.Tensor(
# [[-0.00627048 -0.00901578 -0.0099314 ]
#  [-0.00627706 -0.00902162 -0.00993641]
#  [-0.00627129 -0.00901326 -0.00991671]
#  [-0.00626964 -0.00901418 -0.00992668]], shape=(4, 3), dtype=float32)
# context_vecs.shape: (4, 3)
